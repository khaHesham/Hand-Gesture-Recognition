# %% [markdown]
# ## Histogram Equalization

# %%
import cv2
import matplotlib.pyplot as plt

img1 = cv2.imread('sdsd.jpg')
img2 = cv2.imread('sdsd.jpg', 0)
gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray, 30, 100)
img2 = cv2.resize(img2,(720,500))
# cv2.imshow('img',img)
# img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

hist1 = cv2.calcHist([img2],[0],None,[256],[0,256])
img2_2 = cv2.equalizeHist(img2)
hist2 = cv2.calcHist([img2_2],[0],None,[256],[0,256])
plt.subplot(331),plt.imshow(img2)
plt.subplot(332),plt.plot(hist1)
plt.subplot(334),plt.imshow(img2_2)
plt.subplot(335),plt.plot(hist2)


plt.subplot(337),plt.imshow(gray)
plt.subplot(338),plt.plot(edges)
# Out:
# (<AxesSubplot:>,
# ...
#   ...])
